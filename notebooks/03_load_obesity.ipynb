# %%
import pandas as pd
import os

# %%
obesity_df = df_cdi_full[
    df_cdi_full["Topic"].str.contains("Nutrition", case=False, na=False)
]
obesity_df.shape
# Out:
#   Cell In[24], line 1
#     diabetes_df = (cdi_df_full[cdi_df_full["Topic"] == "Diabetes")   & (cdi_df_full["DataValueType"] == "Crude Prevalence")
#                                                                  ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['
